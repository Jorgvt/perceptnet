# %%
# %load_ext autoreload
# %autoreload 2

# %%
# import os; os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
import numpy as np
import tensorflow as tf

import wandb
from wandb.keras import WandbCallback

from perceptnet.networks import *
from perceptnet.pearson_loss import PearsonCorrelation

from iqadatasets.datasets.tid2008 import TID2008
from iqadatasets.datasets.tid2013 import TID2013
from flayers.callbacks import *

# %% [markdown]
# # Load the data

# %%
cuac = TID2008("/lustre/ific.uv.es/ml/uv075/Databases/IQA/TID/TID2008", exclude_imgs=[25])
cuac_val = TID2013("/lustre/ific.uv.es/ml/uv075/Databases/IQA/TID/TID2013", exclude_imgs=[25])

# %%
dst_train = cuac.dataset
dst_val = cuac_val.dataset
# Out:
# 2023-01-30 00:07:52.741883: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-30 00:07:52.741959: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: mlui02.ific.uv.es
# 2023-01-30 00:07:52.741978: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: mlui02.ific.uv.es
# 2023-01-30 00:07:52.742220: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 520.61.5
# 2023-01-30 00:07:52.742276: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 520.61.5
# 2023-01-30 00:07:52.742289: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 520.61.5
# 2023-01-30 00:07:52.743860: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Wandb config

# %%
config = {
        'train_dataset':'TID2008',
        'test_dataset':'TID2013',
        'epochs':500,
        'learning_rate':3e-4,
        'batch_size':64,
        'kernel_initializer':'ones',
        'gdn_kernel_size':11,
        'learnable_undersampling':False,
        'verbose': 0,
        # 'test_images':['20', '21', '22', '23', '24'],
        # 'test_dists':['05', '10', '15', '20', '24']
    }

# %%
wandb.init(project='PerceptNet2',
            notes="",
            tags=["full", "norm", "min", "excluded non-natural", 'Train_TID2008', 'Test_TID2013'],
            name = 'ExpGaborLast',
            config=config,
            job_type="online")
config = wandb.config
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jorgvt. Use `wandb login --relogin` to force relogin
# wandb version 0.13.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.3
# Run data is saved locally in <code>/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08</code>
# Syncing run <strong><a href="https://wandb.ai/jorgvt/PerceptNet2/runs/18t7lg08" target="_blank">ExpGaborLast</a></strong> to <a href="https://wandb.ai/jorgvt/PerceptNet2" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# # Define the model

# %%
# model = PerceptNetExpGDNGaussian(kernel_initializer=config.kernel_initializer, gdn_kernel_size=config.gdn_kernel_size)
model = PerceptNetExpGaborLast(kernel_initializer=config.kernel_initializer, gdn_kernel_size=config.gdn_kernel_size)

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=config.learning_rate),
              loss=PearsonCorrelation())

# %% [markdown]
# Log the number of trainable weights:

# %%
model.build((None,384,512,3))
num_trainable_vars = np.sum([np.prod(v.shape) for v in model.trainable_variables])
wandb.run.summary["trainable_parameters"] = num_trainable_vars
num_vars = np.sum([np.prod(v.shape) for v in model.weights])
wandb.run.summary["parameters"] = num_vars
print(f"Trainable: {num_trainable_vars} | Vars: {num_vars}")
# Out:
# Trainable: 1994384 | Vars: 2301595.0

# %%
history = model.fit(dst_train.shuffle(buffer_size=100,
                                      reshuffle_each_iteration=True,
                                      seed=42) \
                             .batch(config.batch_size), epochs=config.epochs, 
                    validation_data=dst_val.batch(config.batch_size),
                    callbacks=[WandbCallback(monitor='val_loss',
                                             mode='min',
                                             save_model=True,
                                             save_weights_only=True),
                            #    BatchesSeenLogger(),
                            #    FunctionalFilterLogger(),
                               ],
                    verbose=config.verbose)
# Out:
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# wandb: WARNING Unable to compute FLOPs for this model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.8s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.7s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.4s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.1s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.0s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.1s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.2s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.1s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.4s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.9s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.4s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.1s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.9s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.8s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# ...
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.6s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.0s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 1.1s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.7s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.4s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.7s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, generate_dominion, conv2d_layer_call_fn while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best/assets
# wandb: Adding directory to artifact (/lhome/ext/uv075/uv0752/perceptnet/Notebooks/06_Parametric/wandb/run-20230130_001220-18t7lg08/files/model-best)... Done. 0.5s
# WARNING:tensorflow:`evaluate()` received a value for `sample_weight`, but `weighted_metrics` were not provided.  Did you mean to pass metrics to `weighted_metrics` in `compile()`?  If this is intentional you can pass `weighted_metrics=[]` to `compile()` in order to silence this warning.

# %%
wandb.finish()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 wandb.finish()
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:3565, in finish(exit_code, quiet)
#    3555 """Marks a run as finished, and finishes uploading all data.
#    3556
#    3557 This is used when creating multiple runs in the same process.
#    (...)
#    3562     quiet: Set to true to minimize log output
#    3563 """
#    3564 if wandb.run:
# -> 3565     wandb.run.finish(exit_code=exit_code, quiet=quiet)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:282, in _run_decorator._noop.<locals>.wrapper(self, *args, **kwargs)
#     279         wandb.termwarn(message, repeat=False)
#     280         return cls.Dummy()
# --> 282 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:245, in _run_decorator._attach.<locals>.wrapper(self, *args, **kwargs)
#     243         raise e
#     244     cls._is_attaching = ""
# --> 245 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:1713, in Run.finish(self, exit_code, quiet)
#    1701 @_run_decorator._noop
#    1702 @_run_decorator._attach
#    1703 def finish(self, exit_code: int = None, quiet: Optional[bool] = None) -> None:
#    1704     """Marks a run as finished, and finishes uploading all data.
#    1705
#    1706     This is used when creating multiple runs in the same process. We automatically
#    (...)
#    1711         quiet: Set to true to minimize log output
#    1712     """
# -> 1713     return self._finish(exit_code, quiet)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:1724, in Run._finish(self, exit_code, quiet)
#    1722 for hook in self._teardown_hooks:
#    1723     if hook.stage == TeardownStage.EARLY:
# -> 1724         hook.call()
#    1726 self._atexit_cleanup(exit_code=exit_code)
#    1727 if self._wl and len(self._wl._global_run_stack) > 0:
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/sdk/wandb_init.py:404, in _WandbInit._jupyter_teardown(self)
#     402 """Teardown hooks and display saving, called with wandb.finish."""
#     403 ipython = self.notebook.shell
# --> 404 self.notebook.save_history()
#     405 if self.notebook.save_ipynb():
#     406     res = self.run.log_code(root=None)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/wandb/jupyter.py:446, in Notebook.save_history(self)
#     444     return
#     445 cells = []
# --> 446 hist = list(self.shell.history_manager.get_range(output=True))
#     447 if len(hist) <= 1 or not self.settings.save_code:
#     448     logger.info("not saving jupyter history")
#
# TypeError: get_range() missing 1 required positional argument: 'session'
